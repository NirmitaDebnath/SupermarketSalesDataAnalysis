# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\nirmi\OneDrive\Desktop\ALL\EXCEL FILES\supermarket_sales.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender
# 0    750-67-8428      A     Yangon        Member  Female  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%  SELLING PRICE
# 0         Health and beauty       74.69         7  26.1415       548.9715  \
# 1    Electronic accessories       15.28         5   3.8200        80.2200
# ...

# %%
df.set_index('Invoice ID',inplace=True)

# %%
df.head()
# Out:
#             Branch       City Customer type  Gender            Product line
# Invoice ID
# 750-67-8428      A     Yangon        Member  Female       Health and beauty  \
# 226-31-3081      C  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108      A     Yangon        Normal    Male      Home and lifestyle
# 123-19-1176      A     Yangon        Member    Male       Health and beauty
# 373-73-7910      A     Yangon        Normal    Male       Sports and travel
#
#              Unit price  Quantity   Tax 5%  SELLING PRICE        Date
# Invoice ID
# 750-67-8428       74.69         7  26.1415       548.9715  01-05-2019  \
# 226-31-3081       15.28         5   3.8200        80.2200  03-08-2019
# 631-41-3108       46.33         7  16.2155       340.5255  03-03-2019
# 123-19-1176       58.22         8  23.2880       489.0480   1-27-2019
# 373-73-7910       86.31         7  30.2085       634.3785  02-08-2019
#
# ...

# %%
df.tail()
# Out:
#             Branch       City Customer type  Gender         Product line
# Invoice ID
# 233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty  \
# 303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 727-02-1313      A     Yangon        Member    Male   Food and beverages
# 347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#              Unit price  Quantity   Tax 5%  SELLING PRICE        Date
# Invoice ID
# 233-67-5758       40.35         1   2.0175        42.3675   1-29-2019  \
# 303-96-2227       97.38        10  48.6900      1022.4900  03-02-2019
# 727-02-1313       31.84         1   1.5920        33.4320  02-09-2019
# 347-56-2442       65.82         1   3.2910        69.1110   2-22-2019
# 849-09-3807       88.34         7  30.9190       649.2990   2-18-2019
#
#                  Time  Payment  COST PRICE  gross margin percentage
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'SELLING PRICE', 'Date', 'Time',
#        'Payment', 'COST PRICE', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 750-67-8428 to 849-09-3807
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Branch                   1000 non-null   object
#  1   City                     1000 non-null   object
#  2   Customer type            1000 non-null   object
#  3   Gender                   1000 non-null   object
#  4   Product line             1000 non-null   object
#  5   Unit price               1000 non-null   float64
#  6   Quantity                 1000 non-null   int64
#  7   Tax 5%                   1000 non-null   float64
#  8   SELLING PRICE            1000 non-null   float64
#  9   Date                     1000 non-null   object
#  10  Time                     1000 non-null   object
#  11  Payment                  1000 non-null   object
#  12  COST PRICE               1000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# SELLING PRICE              0
# Date                       0
# Time                       0
# Payment                    0
# COST PRICE                 0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%  SELLING PRICE  COST PRICE
# count  1000.000000  1000.000000  1000.000000    1000.000000  1000.00000  \
# mean     55.672130     5.510000    15.379369     322.966749   307.58738
# std      26.494628     2.923431    11.708825     245.885335   234.17651
# min      10.080000     1.000000     0.508500      10.678500    10.17000
# 25%      32.875000     3.000000     5.924875     124.422375   118.49750
# 50%      55.230000     5.000000    12.088000     253.848000   241.76000
# 75%      77.935000     8.000000    22.445250     471.350250   448.90500
# max      99.960000    10.000000    49.650000    1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count                1000.0000   1000.000000  1000.00000
# mean                    4.7619     15.379369     6.97270
# std                     0.0000     11.708825     1.71858
# min                     4.7619      0.508500     4.00000
# ...

# %%
df.to_numpy()
# Out:
# array([['A', 'Yangon', 'Member', ..., 4.7619, 26.1415, 9.1],
#        ['C', 'Naypyitaw', 'Normal', ..., 4.7619, 3.82, 9.6],
#        ['A', 'Yangon', 'Normal', ..., 4.7619, 16.2155, 7.4],
#        ...,
#        ['A', 'Yangon', 'Member', ..., 4.7619, 1.592, 7.7],
#        ['A', 'Yangon', 'Normal', ..., 4.7619, 3.291, 4.1],
#        ['A', 'Yangon', 'Member', ..., 4.7619, 30.919, 6.6]], dtype=object)

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# **Q.WHAT IS THE OVERALL SALES TREND?**

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Date'].min()
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2019-03-30 00:00:00')

# %%
df['month-year']=df['Date'].apply(lambda x: x.strftime('%Y-%m'))

# %%
df['month']=df['Date'].apply(lambda x: x.strftime('%m'))

# %%
df['month']
# Out:
# Invoice ID
# 750-67-8428    01
# 226-31-3081    03
# 631-41-3108    03
# 123-19-1176    01
# 373-73-7910    02
#                ..
# 233-67-5758    01
# 303-96-2227    03
# 727-02-1313    02
# 347-56-2442    02
# 849-09-3807    02
# Name: month, Length: 1000, dtype: object

# %%
df['month-year']
# Out:
# Invoice ID
# 750-67-8428    2019-01
# 226-31-3081    2019-03
# 631-41-3108    2019-03
# 123-19-1176    2019-01
# 373-73-7910    2019-02
#                 ...
# 233-67-5758    2019-01
# 303-96-2227    2019-03
# 727-02-1313    2019-02
# 347-56-2442    2019-02
# 849-09-3807    2019-02
# Name: month-year, Length: 1000, dtype: object

# %%
df.groupby(['month'],as_index=False)['SELLING PRICE'].sum()
# Out:
#   month  SELLING PRICE
# 0    01     116291.868
# 1    02      97219.374
# 2    03     109455.507

# %%
sns.barplot(x='month',y='SELLING PRICE',data=df.groupby(['month'],as_index=False)['SELLING PRICE'].sum(),palette='Paired')
plt.show()

# %%
df.groupby(['month'],as_index=False)['Quantity'].sum()
# Out:
#   month  Quantity
# 0    01      1965
# 1    02      1654
# 2    03      1891

# %%
sns.barplot(x='month',y='Quantity',data=df.groupby(['month'],as_index=False)['Quantity'].sum(),palette='Paired')
plt.show()

# %% [markdown]
# **WHICH ARE THE TOP PRODUCTS BY SALE?**

# %%
df['Product line'].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
df.groupby(['Product line'],as_index=False)['SELLING PRICE'].sum()
# Out:
#              Product line  SELLING PRICE
# 0  Electronic accessories     54337.5315
# 1     Fashion accessories     54305.8950
# 2      Food and beverages     56144.8440
# 3       Health and beauty     49193.7390
# 4      Home and lifestyle     53861.9130
# 5       Sports and travel     55122.8265

# %%
sns.barplot(x='Product line',y='SELLING PRICE',data=df.groupby(['Product line'],as_index=False)['SELLING PRICE'].sum(),palette='Set2')
plt.show()

# %%
df.groupby(['Product line'],as_index=False)['Rating'].mean()
# Out:
#              Product line    Rating
# 0  Electronic accessories  6.924706
# 1     Fashion accessories  7.029213
# 2      Food and beverages  7.113218
# 3       Health and beauty  7.003289
# 4      Home and lifestyle  6.837500
# 5       Sports and travel  6.916265

# %%
sns.barplot(x='Product line',y='Rating',data=df.groupby(['Product line'],as_index=False)['Rating'].mean(),palette='Set2')
plt.show()

# %% [markdown]
# **GENDER**

# %%
df.groupby(['Gender'],as_index=False)['SELLING PRICE'].sum()
# Out:
#    Gender  SELLING PRICE
# 0  Female     167882.925
# 1    Male     155083.824

# %%
sns.barplot(x='Gender',y='SELLING PRICE',data=df.groupby(['Gender'],as_index=False)['SELLING PRICE'].sum(),palette='rocket')
plt.show()

# %%
df.groupby(['Gender'],as_index=False)['Quantity'].sum()
# Out:
#    Gender  Quantity
# 0  Female      2869
# 1    Male      2641

# %%
sns.barplot(x='Gender',y='Quantity',data=df.groupby(['Gender'],as_index=False)['Quantity'].sum(),palette='rocket')
plt.show()

# %%
df.groupby(['Product line',],as_index=False)['gross income'].sum()
# Out:
#              Product line  gross income
# 0  Electronic accessories     2587.5015
# 1     Fashion accessories     2585.9950
# 2      Food and beverages     2673.5640
# 3       Health and beauty     2342.5590
# 4      Home and lifestyle     2564.8530
# 5       Sports and travel     2624.8965

# %%
sns.barplot(x='Product line',y='gross income',data=df.groupby(['Product line'],as_index=False)['gross income'].sum())
plt.show()

# %%
df.groupby(['City'],as_index=False)['SELLING PRICE'].sum()
# Out:
#         City  SELLING PRICE
# 0   Mandalay    106197.6720
# 1  Naypyitaw    110568.7065
# 2     Yangon    106200.3705

# %%
sns.barplot(x='City',y='SELLING PRICE',data=df.groupby(['City'],as_index=False)['SELLING PRICE'].sum())
plt.show()

# %%
sns.pairplot(df)
